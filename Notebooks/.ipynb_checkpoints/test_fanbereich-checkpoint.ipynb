# %%
import pandas as pd
from bs4 import BeautifulSoup
import numpy as np
import requests
import html5lib

# %%
pip install html5lib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
df = pd.read_excel("/Users/henriksoeder/Documents/Arbeit/Python/Football_Scrape/Tabellen/fanbereich_übersicht.xlsx")
df.head(3)
# Out:
#               Verein                          Name  \
# 0        FC Augsburg                 Original 1907
# 1  Borussia Dortmund           Südtribüne Dortmund
# 2         1. FC Köln  Coloniacs – Ultrà 1. FC Köln
#
#                             Fanseite                Vereinsseite  \
# 0  https://augsburg.original1907.de/  https://www.fcaugsburg.de/
# 1  https://suedtribuene-dortmund.de/         https://www.bvb.de/
# 2       https://coloniacs-ultra.com/              https://fc.de/
#
#                                           Bild Titel  \
# 0                             Bilder | Original 1907
# 1             Saison 2023/2024 – Südtribüne Dortmund
# 2  12. Spieltag: 1. FC Köln – FC Bayern München –...
#
#                                        Neuste Bilder  \
# 0      http://augsburg.original1907.de/p/bilder.html
# 1  https://suedtribuene-dortmund.de/saison-2023-2...
# 2  https://coloniacs-ultra.com/bilder/saison-2023...
#
#                                       Text Titel  \
# ...

# %%
df_zuschauer= pd.read_html("https://www.fussballmafia.de/zuschauertabelle/")

# %%
df_zuschauer[0].head()
# Out:
#                Platz             Verein Unnamed: 2_level_0 ZuschauerØ  \
#   Unnamed: 0_level_1 Unnamed: 1_level_1             Gesamt    ø33.903
# 0                NaN                NaN                NaN        NaN
# 1                NaN                NaN     Bayern München    ø75.000
# 2                NaN                NaN      Werder Bremen    ø41.786
# 3                NaN                NaN  Borussia Dortmund    ø81.365
# 4                NaN                NaN         1. FC Köln    ø49.683
#
#       Gesamt ausverkaufter Heimbereich Stadion-Auslastung  \
#   ∑7.933.307               149 von 234             91,33%
# 0        NaN                       NaN                NaN
# 1    450.000           6 von 6 Spielen               100%
# 2    292.500           7 von 7 Spielen               100%
# 3    569.555           7 von 7 Spielen               100%
# 4    298.100           6 von 6 Spielen                99%
#
# ...

# %%
pd.read_html("https://www.fussballmafia.de/zuschauertabelle/3-liga/")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 pd.read_html("https://www.fussballmafia.de/zuschauertabelle/3-liga/")
#
# File ~/Documents/Arbeit/Ironhack/Prework/Programme/anaconda3/lib/python3.11/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# ...

# %%
pip list
# Out:
# Package                       Version
# ----------------------------- ---------
# aiobotocore                   2.5.0
# aiofiles                      22.1.0
# aiohttp                       3.8.3
# aioitertools                  0.7.1
# aiosignal                     1.2.0
# aiosqlite                     0.18.0
# alabaster                     0.7.12
# altair                        5.1.2
# anaconda-catalogs             0.2.0
# anaconda-client               1.12.0
# anaconda-navigator            2.4.2
# anaconda-project              0.11.1
# anyio                         3.5.0
# appdirs                       1.4.4
# applaunchservices             0.3.0
# appnope                       0.1.2
# appscript                     1.1.2
# argon2-cffi                   21.3.0
# argon2-cffi-bindings          21.2.0
# arrow                         1.2.3
# astroid                       2.14.2
# astropy                       5.1
# asttokens                     2.0.5
# async-timeout                 4.0.2
# ...
