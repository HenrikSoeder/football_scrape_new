# %%
import pandas as pd
from bs4 import BeautifulSoup
import numpy as np
import requests
import html5lib
import datetime

# %%
df_zuschauer_3= pd.read_html("https://www.fussballmafia.de/zuschauertabelle/3-liga/")
df_3 = df_zuschauer_3[0]


df_zuschauer_3 = df_3

df_zuschauer_3.drop("Platz", axis = 1, inplace = True)
df_zuschauer_3.drop("Verein", axis = 1, inplace = True)
df_zuschauer_3.drop("Gesamt", axis = 1, inplace = True)
df_zuschauer_3.drop("ausverkaufter Heimbereich", axis = 1, inplace = True)
df_zuschauer_3.drop("Spielansetzung", axis = 1, inplace = True)
df_zuschauer_3.drop("Höchstwert", axis = 1, inplace = True)
df_zuschauer_3.drop("Tiefswert", axis = 1, inplace = True)

df_zuschauer_3
# Out:
# /var/folders/bk/02hh56sx1b7622qtqhym98tc0000gn/T/ipykernel_23888/3806425794.py:7: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   df_zuschauer_3.drop("Platz", axis = 1, inplace = True)
# /var/folders/bk/02hh56sx1b7622qtqhym98tc0000gn/T/ipykernel_23888/3806425794.py:8: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   df_zuschauer_3.drop("Verein", axis = 1, inplace = True)
# /var/folders/bk/02hh56sx1b7622qtqhym98tc0000gn/T/ipykernel_23888/3806425794.py:9: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   df_zuschauer_3.drop("Gesamt", axis = 1, inplace = True)
# /var/folders/bk/02hh56sx1b7622qtqhym98tc0000gn/T/ipykernel_23888/3806425794.py:10: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   df_zuschauer_3.drop("ausverkaufter Heimbereich", axis = 1, inplace = True)
# /var/folders/bk/02hh56sx1b7622qtqhym98tc0000gn/T/ipykernel_23888/3806425794.py:11: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   df_zuschauer_3.drop("Spielansetzung", axis = 1, inplace = True)
# /var/folders/bk/02hh56sx1b7622qtqhym98tc0000gn/T/ipykernel_23888/3806425794.py:12: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   df_zuschauer_3.drop("Höchstwert", axis = 1, inplace = True)
# /var/folders/bk/02hh56sx1b7622qtqhym98tc0000gn/T/ipykernel_23888/3806425794.py:13: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   df_zuschauer_3.drop("Tiefswert", axis = 1, inplace = True)
#     Unnamed: 2_level_0 ZuschauerØ Stadion-Auslastung
#                 Gesamt     ø9.649             52,84%
# 0                  NaN        NaN                NaN
# 1        Hallescher FC     ø7.609                51%
# 2      Rot-Weiss Essen    ø17.131                86%
# 3        Viktoria Köln     ø4.669                47%
# 4              SC Verl     ø2.410                46%
# 5        SV Sandhausen     ø4.371                28%
# 6           VfB Lübeck     ø6.030                55%
# 7     TSV 1860 München    ø15.000               100%
# 8     Waldhof Mannheim     ø8.119                33%
# 9      Preußen Münster     ø9.862                78%
# 10        BVB Amateure     ø4.157                19%
# 11     Jahn Regensburg     ø8.316                55%
# 12  SpVgg Unterhaching     ø4.069                27%
# 13   Arminia Bielefeld    ø17.435                64%
# 14      Dynamo Dresden    ø29.229                91%
# 15   1. FC Saarbrücken    ø11.201                70%
# 16        SSV Ulm 1846    ø10.468                62%
# 17        MSV Duisburg    ø13.951                44%
# 18      SC Freiburg II     ø2.225                 9%
# 19    FC Ingolstadt 04     ø6.597                42%
# 20      Erzgebirge Aue     ø9.171                59%

# %%
df_zuschauer= pd.read_html("https://www.fussballmafia.de/zuschauertabelle/")
df_1 = df_zuschauer[0]
#df_zuschauer_3 = pd.read_html("https://www.fussballmafia.de/zuschauertabelle/3-liga/")
#df_2 = df_zuschauer_3[0]

df_zuschauer = df_1

df_zuschauer.drop("Platz", axis = 1, inplace = True)
df_zuschauer.drop("Verein", axis = 1, inplace = True)
df_zuschauer.drop("Gesamt", axis = 1, inplace = True)
df_zuschauer.drop("ausverkaufter Heimbereich", axis = 1, inplace = True)
df_zuschauer.drop("Spielansetzung", axis = 1, inplace = True)
df_zuschauer.drop("Höchstwert", axis = 1, inplace = True)
df_zuschauer.drop("Tiefswert", axis = 1, inplace = True)

df_zuschauer
# Out:
# /var/folders/bk/02hh56sx1b7622qtqhym98tc0000gn/T/ipykernel_23888/2823225027.py:8: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   df_zuschauer.drop("Platz", axis = 1, inplace = True)
# /var/folders/bk/02hh56sx1b7622qtqhym98tc0000gn/T/ipykernel_23888/2823225027.py:9: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   df_zuschauer.drop("Verein", axis = 1, inplace = True)
# /var/folders/bk/02hh56sx1b7622qtqhym98tc0000gn/T/ipykernel_23888/2823225027.py:10: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   df_zuschauer.drop("Gesamt", axis = 1, inplace = True)
# /var/folders/bk/02hh56sx1b7622qtqhym98tc0000gn/T/ipykernel_23888/2823225027.py:11: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   df_zuschauer.drop("ausverkaufter Heimbereich", axis = 1, inplace = True)
# /var/folders/bk/02hh56sx1b7622qtqhym98tc0000gn/T/ipykernel_23888/2823225027.py:12: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   df_zuschauer.drop("Spielansetzung", axis = 1, inplace = True)
# /var/folders/bk/02hh56sx1b7622qtqhym98tc0000gn/T/ipykernel_23888/2823225027.py:13: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   df_zuschauer.drop("Höchstwert", axis = 1, inplace = True)
# /var/folders/bk/02hh56sx1b7622qtqhym98tc0000gn/T/ipykernel_23888/2823225027.py:14: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   df_zuschauer.drop("Tiefswert", axis = 1, inplace = True)
#           Unnamed: 2_level_0 ZuschauerØ Stadion-Auslastung
#                       Gesamt    ø33.903             91,33%
# 0                        NaN        NaN                NaN
# 1             Bayern München    ø75.000               100%
# 2              Werder Bremen    ø41.786               100%
# 3          Borussia Dortmund    ø81.365               100%
# 4                 1. FC Köln    ø49.683                99%
# 5            1. FSV Mainz 05    ø32.103                96%
# 6         1. FC Union Berlin    ø21.677                98%
# 7        Bayer 04 Leverkusen    ø29.747                98%
# 8                         RB    ø44.951                95%
# 9        Eintracht Frankfurt    ø55.850               100%
# 10           SV Darmstadt 98    ø17.810               100%
# 11             VfL Wolfsburg    ø27.174                94%
# 12     1. FC Heidenheim 1846    ø15.000               100%
# 13       TSG 1899 Hoffenheim    ø25.973                86%
# 14               SC Freiburg    ø34.239                99%
# 15  Borussia Mönchengladbach    ø51.093                95%
# 16               FC Augsburg    ø28.642                93%
# 17             VfB Stuttgart    ø53.583                99%
# 18                VfL Bochum    ø26.000               100%
# 19             FC Schalke 04    ø61.538                99%
# 20              Hamburger SV    ø56.511                99%
# 21      1. FC Kaiserslautern    ø42.730                86%
# 22              FC St. Pauli    ø29.486               100%
# 23             Karlsruher SC    ø27.606                87%
# 24             VfL Osnabrück    ø15.391                98%
# 25           1. FC Magdeburg    ø25.423                91%
# 26        SV Wehen Wiesbaden     ø9.885                79%
# 27                Hertha BSC    ø46.615                63%
# 28        Fortuna Düsseldorf    ø37.376                72%
# 29               Hannover 96    ø38.800                81%
# 30             SV Elversberg     ø8.845                87%
# 31           SC Paderborn 07    ø13.516                90%
# 32               SpVgg Fürth    ø11.017                66%
# 33            1. FC Nürnberg    ø37.778                77%
# 34          FC Hansa Rostock    ø25.775                97%
# 35    Eintracht Braunschweig    ø20.222                87%
# 36             Holstein Kiel    ø13.027                87%

# %%
df_zuschauer.rename(columns = {"Unnamed: 2_level_0": "Verein"}, inplace = True)
df_zuschauer.rename(columns = {"ZuschauerØ": "Zuschauerschnitt"}, inplace = True)
df_zuschauer.rename(columns = {"Stadion-Auslastung": "Stadion_auslastung"},  inplace = True)

df_zuschauer.reset_index(inplace=True)
df_zuschauer.drop('index', axis=1, inplace=True)
# Out:
# /var/folders/bk/02hh56sx1b7622qtqhym98tc0000gn/T/ipykernel_23888/3491457093.py:6: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   df_zuschauer.drop('index', axis=1, inplace=True)

# %%
df_zuschauer_3.rename(columns = {"Unnamed: 2_level_0": "Verein"}, inplace = True)
df_zuschauer_3.rename(columns = {"ZuschauerØ": "Zuschauerschnitt"}, inplace = True)
df_zuschauer_3.rename(columns = {"Stadion-Auslastung": "Stadion_auslastung"},  inplace = True)

df_zuschauer_3.reset_index(inplace=True)
df_zuschauer_3.drop('index', axis=1, inplace=True)
# Out:
# /var/folders/bk/02hh56sx1b7622qtqhym98tc0000gn/T/ipykernel_23888/3567937113.py:6: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   df_zuschauer_3.drop('index', axis=1, inplace=True)
